# %% [markdown]
# # 세부영역별 세부사업명·주요내용 핵심 단어 시각화
#
# 이슈 #116의 재현 노트북이다. 사람 검토가 완료된 2016~2024 통합 영역분류 워크북을 사용해 명사 TF-IDF, 워드클라우드, 막대그래프와 중복 제거 민감도 결과를 생성한다.

# %%
from scripts.build_subarea_keyword_visualizations import (
    DEFAULT_WORKBOOK,
    build_outputs,
    resolve_korean_font,
)

metadata = build_outputs(
    DEFAULT_WORKBOOK.resolve(),
    font_path=resolve_korean_font(),
)
metadata

# %%
from scripts.verify_subarea_keyword_outputs import run_checks

[(check.name, check.passed, check.detail) for check in run_checks()]
